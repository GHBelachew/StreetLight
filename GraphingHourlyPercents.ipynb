# %%
import pandas as pd

# %%
# Import plotting libraries
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Set plot style
print(plt.style.available)
mpl.style.use(['ggplot']) # optional: for ggplot-like style
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
df = pd.read_excel('L:/Belachew/Tools/Python/PercentTest/Data/LinksPctvolume_SR40Proj.xlsx')

# %%
df
# Out:
#           DayTime  Pittsburgh St - N. of SR 43 - NB  \
# 0      (12am-1am)                          0.653046
# 1       (1am-2am)                          0.373169
# 2       (2am-3am)                          0.335852
# 3       (3am-4am)                          0.419815
# 4       (4am-5am)                          1.436701
# 5       (5am-6am)                          1.763224
# 6       (6am-7am)                          2.285661
# 7       (7am-8am)                          4.757907
# 8       (8am-9am)                          4.701931
# 9      (9am-10am)                          4.776565
# 10    (10am-11am)                          5.373636
# 11  (11am-12noon)                          6.203937
# 12   (12noon-1pm)                          6.698386
# 13      (1pm-2pm)                          6.427838
# 14      (2pm-3pm)                          7.789906
# 15      (3pm-4pm)                          7.957832
# 16      (4pm-5pm)                          8.816121
# ...

# %%
df.set_index('DayTime', inplace = True)  #inplace is so important here to repace the x axis lables

# %%
# df2 = df.iloc[:, 1:] = df.iloc[:, 1:].div(df['total'], axis=0).mul(100).round(2).astype(str)

# create percent of rows 
#df2= (df.apply(lambda x: x/sum(x)*100, axis=0))/100


# create percent of colums
#df3= (df.apply(lambda x: x/sum(x)*100, axis=1))/100

# %%
#df2

# %%
#df3

# %%
# Plot
#Plot popualtion data
df[['Pittsburgh St - N. of SR 43 - NB','Pittsburgh St - N. of SR 43 - SB']].plot(kind ='line', figsize= (10,6))

plt.title('Percent of rows')
plt.ylabel('Percent')
plt.xlabel('DayTime')
plt.xticks(rotation=90)
plt.show()

# %%
# Resouces
#https://video.search.yahoo.com/yhs/search?fr=yhs-pty-browser_wavebrowser&ei=UTF-8&hsimp=yhs-browser_wavebrowser&hspart=pty&param1=20210315&param2=c7343040-4bc9-436e-8352-1c38d0b45c29&param3=wav%7EUS%7Eappfocus1%7E&param4=d-cp12393676741-lp0-hh3-obem-wav-nt0-igYEizrpWEBkyYnlkeaQLA-ab27-w64-brwsr-ntb-ntp%7EChrome%7Ehow+to+give+dynaimc+plot+title+in+pandas+plot%7EB2D7D7656EB4E5153688637C8FBF7B49%7EWin10&p=how+to+give+dynaimc+plot+title+in+pandas+plot&type=A1-brwsr-%7E2021-12%7E#id=1&vid=42b03c702254116458f39262ef0c2856&action=click
